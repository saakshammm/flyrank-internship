# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saakshammm/flyrank-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Classification. I want to classify pages as declining or not declining based on observable page and search signals.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# The target is is_declining_label, derived from the observed trend_direction field. A page is labeled declining when trend_direction is down.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Precision@50. A good model should put a high proportion of genuinely declining pages in the top 50 recommendations, because those are the pages the team will review first.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/saakshammm/flyrank-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

df[["content_id", "client_id", "trend_direction", "trend_pct"]].head()
# Out:
#              content_id          client_id trend_direction  trend_pct
# 0  content_304f48230142  client_f369cb89fc            down      -41.4
# 1  content_a1fb4e703a9e  client_4e07408562            down      -57.7
# 2  content_9aa793d4d895  client_7f2253d7e2            down      -60.9
# 3  content_331d6c4de07b  client_19581e27de          stable      -13.8
# 4  content_d99b7a2d90ca  client_3fdba35f04            down      -34.7

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# The relationship between signals and decline is likely too complex for one fixed threshold. Different pages can have different combinations of traffic, rankings, engagement, content characteristics, and search signals. ML can combine these signals and rank pages more consistently than a simple rule.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
